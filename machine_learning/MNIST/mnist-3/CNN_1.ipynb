# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/MNIST/mnist-3
# !ls
# !pwd
# Out:
# drive  sample_data
# /content
# /content/drive/My Drive/MNIST/mnist-3

# %%
# !ls
# !pwd
# Out:
# Untitled0.ipynb
# /content/drive/My Drive/MNIST/mnist-3

# %%
# 载入库
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()

#载入数据
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
print(train_images.shape)
print(train_labels.shape)
# Out:
# (60000, 28, 28)
# (60000,)

# %%
train_images = train_images.reshape(60000, 28, 28, 1)
test_images = test_images.reshape(10000, 28, 28, 1)
#维度变换

# %%
train_images = train_images / 255
test_images = test_images/ 255
# 归一化

# %%
train_labels = np.array(pd.get_dummies(train_labels))
test_labels = np.array(pd.get_dummies(test_labels))

#独热编码

# %%
model = tf.keras.Sequential()

# %%
model.add(tf.keras.layers.Conv2D(filters = 6,kernel_size = (5,5),input_shape=(28,28,1),activation = "relu"))#默认padding='valid'，strides=1
model.add(tf.keras.layers.MaxPooling2D(pool_size = (2, 2)))#默认strides=None
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(64, activation='sigmoid'))
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 24, 24, 6)         156
#
#  max_pooling2d (MaxPooling2D  (None, 12, 12, 6)        0
#  )
#
#  flatten (Flatten)           (None, 864)               0
#
#  dense (Dense)               (None, 64)                55360
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 56,166
# Trainable params: 56,166
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['acc'])

# %%
history = model.fit(train_images,train_labels,epochs = 10,validation_data=(test_images,test_labels))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.2891 - acc: 0.9273 - val_loss: 0.1224 - val_acc: 0.9671
# Epoch 2/10
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.0916 - acc: 0.9743 - val_loss: 0.0735 - val_acc: 0.9782
# Epoch 3/10
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.0666 - acc: 0.9804 - val_loss: 0.0539 - val_acc: 0.9829
# Epoch 4/10
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.0513 - acc: 0.9856 - val_loss: 0.0560 - val_acc: 0.9823
# Epoch 5/10
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.0414 - acc: 0.9881 - val_loss: 0.0475 - val_acc: 0.9851
# Epoch 6/10
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.0330 - acc: 0.9906 - val_loss: 0.0468 - val_acc: 0.9841
# Epoch 7/10
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.0277 - acc: 0.9921 - val_loss: 0.0411 - val_acc: 0.9872
# Epoch 8/10
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.0219 - acc: 0.9936 - val_loss: 0.0405 - val_acc: 0.9866
# Epoch 9/10
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.0187 - acc: 0.9950 - val_loss: 0.0410 - val_acc: 0.9873
# Epoch 10/10
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.0158 - acc: 0.9960 - val_loss: 0.0354 - val_acc: 0.9884

# %%
model.evaluate(test_images,test_labels)
